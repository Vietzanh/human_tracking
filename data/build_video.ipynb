# %%
import subprocess

frame_folder = "/home/anhtv/ETC/MOT15/train/ADL-Rundle-8/img1"

subprocess.run([
    "ffmpeg",
    "-y",
    "-framerate", "30",
    "-i", f"{frame_folder}/%06d.jpg",
    "-c:v", "libx264",
    "-preset", "fast",
    "-tune", "zerolatency",
    "-pix_fmt", "yuv420p",
    "-profile:v", "baseline",
    "-level", "3.0",
    "output_h264.mp4"
])

print("Done! Created output_h264.mp4")
# Out:
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
# ...
